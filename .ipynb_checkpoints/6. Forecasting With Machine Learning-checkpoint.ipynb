# %% [markdown]
# ### Defining the Forecasting Task
# -  two things to establish before designing a forecasting model
#     - what information is available at the time a forecast is made (features)
#     - the time period during which you require forecasted values (target)
#     ![image.png](attachment:image.png)

# %%
import numpy as np
import pandas as pd

N = 20
ts = pd.Series(
    np.arange(N),
    index=pd.period_range(start='2010', freq='A', periods=N, name='Year'),
    dtype=pd.Int8Dtype,
)

# Lag features
X = pd.DataFrame({
    'y_lag_2': ts.shift(2),
    'y_lag_3': ts.shift(3),
    'y_lag_4': ts.shift(4),
    'y_lag_5': ts.shift(5),
    'y_lag_6': ts.shift(6),    
})

# Multistep targets
y = pd.DataFrame({
    'y_step_3': ts.shift(-2),
    'y_step_2': ts.shift(-1),
    'y_step_1': ts,
})

data = pd.concat({'Targets': y, 'Features': X}, axis=1)

data.head(10).style.set_properties(['Targets'], **{'background-color': 'LavenderBlush'}) \
                   .set_properties(['Features'], **{'background-color': 'Lavender'})
# Out:
# <style type="text/css">
# #T_645bd_row0_col0, #T_645bd_row0_col1, #T_645bd_row0_col2, #T_645bd_row1_col0, #T_645bd_row1_col1, #T_645bd_row1_col2, #T_645bd_row2_col0, #T_645bd_row2_col1, #T_645bd_row2_col2, #T_645bd_row3_col0, #T_645bd_row3_col1, #T_645bd_row3_col2, #T_645bd_row4_col0, #T_645bd_row4_col1, #T_645bd_row4_col2, #T_645bd_row5_col0, #T_645bd_row5_col1, #T_645bd_row5_col2, #T_645bd_row6_col0, #T_645bd_row6_col1, #T_645bd_row6_col2, #T_645bd_row7_col0, #T_645bd_row7_col1, #T_645bd_row7_col2, #T_645bd_row8_col0, #T_645bd_row8_col1, #T_645bd_row8_col2, #T_645bd_row9_col0, #T_645bd_row9_col1, #T_645bd_row9_col2 {
#   background-color: LavenderBlush;
# }
# ...

# %% [markdown]
# ### Multistep Forecasting Strategies
# - 4 strategies for producing the multiple target steps required for a forecast
#     - Multioutput model![image.png](attachment:image.png)
#     - Direct strategy ![image-2.png](attachment:image-2.png)
#     - Recursive strategy ![image-3.png](attachment:image-3.png)
#     - DirRec strategy ![image-4.png](attachment:image-4.png)

# %%
#Multioutput + Direct 전략 사용
# forecasting task to have an 8-week horizon with a 1-week lead time

from pathlib import Path
from warnings import simplefilter

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split
from xgboost import XGBRegressor

simplefilter("ignore")

# Set Matplotlib defaults
plt.style.use("seaborn-whitegrid")
plt.rc("figure", autolayout=True, figsize=(11, 4))
plt.rc(
    "axes",
    labelweight="bold",
    labelsize="large",
    titleweight="bold",
    titlesize=16,
    titlepad=10,
)
plot_params = dict(
    color="0.75",
    style=".-",
    markeredgecolor="0.25",
    markerfacecolor="0.25",
)
# %config InlineBackend.figure_format = 'retina'


def plot_multistep(y, every=1, ax=None, palette_kwargs=None):
    palette_kwargs_ = dict(palette='husl', n_colors=16, desat=None)
    if palette_kwargs is not None:
        palette_kwargs_.update(palette_kwargs)
    palette = sns.color_palette(**palette_kwargs_)
    if ax is None:
        fig, ax = plt.subplots()
    ax.set_prop_cycle(plt.cycler('color', palette))
    for date, preds in y[::every].iterrows():
        preds.index = pd.period_range(start=date, periods=len(preds))
        preds.plot(ax=ax)
    return ax


flu_trends = pd.read_csv("./csv/flu-trends.csv")
flu_trends.set_index(
    pd.PeriodIndex(flu_trends.Week, freq="W"),
    inplace=True,
)
flu_trends.drop("Week", axis=1, inplace=True)

# %%
flu_trends
# Out:
#                        AInfluenza  AcuteBronchitis  BodyTemperature  \
# Week
# 2009-06-29/2009-07-05          36               20               43
# 2009-07-06/2009-07-12          25               19               40
# 2009-07-13/2009-07-19          24               30               45
# 2009-07-20/2009-07-26          23               19               40
# 2009-07-27/2009-08-02          27               21               44
# ...                           ...              ...              ...
# 2016-05-30/2016-06-05           5               46               50
# 2016-06-06/2016-06-12           5               47               49
# 2016-06-13/2016-06-19           4               47               48
# 2016-06-20/2016-06-26           3               47               51
# 2016-06-27/2016-07-03           3               48               49
#
#                        BraunThermoscan  BreakAFever  Bronchitis  ChestCold  \
# Week
# ...

# %%
def make_lags(ts, lags, lead_time=1):
    return pd.concat(
        {
            f'y_lag_{i}': ts.shift(i)
            for i in range(lead_time, lags + lead_time)
        },
        axis=1)


# Four weeks of lag features
y = flu_trends.FluVisits.copy()
X = make_lags(y, lags=4).fillna(0.0)


def make_multistep_target(ts, steps):
    return pd.concat(
        {f'y_step_{i + 1}': ts.shift(-i)
         for i in range(steps)},
        axis=1)


# 8주간의 목표값 생성 및 결측값 제거
y = make_multistep_target(y, steps=8).dropna()

#지연 값 생성으로 인해 인덱스가 일치하지 않으므로, align 메서드를 사용하여 특징과 목표 데이터의 인덱스를 맞춥니다.
y, X = y.align(X, join='inner', axis=0)

# %%
X
# Out:
#                        y_lag_1  y_lag_2  y_lag_3  y_lag_4
# Week
# 2009-06-29/2009-07-05      0.0      0.0      0.0      0.0
# 2009-07-06/2009-07-12    180.0      0.0      0.0      0.0
# 2009-07-13/2009-07-19    115.0    180.0      0.0      0.0
# 2009-07-20/2009-07-26    132.0    115.0    180.0      0.0
# 2009-07-27/2009-08-02    109.0    132.0    115.0    180.0
# ...                        ...      ...      ...      ...
# 2016-04-11/2016-04-17    712.0    955.0   1100.0   1326.0
# 2016-04-18/2016-04-24    616.0    712.0    955.0   1100.0
# 2016-04-25/2016-05-01    578.0    616.0    712.0    955.0
# 2016-05-02/2016-05-08    455.0    578.0    616.0    712.0
# 2016-05-09/2016-05-15    305.0    455.0    578.0    616.0
#
# [359 rows x 4 columns]

# %%
y
# Out:
#                        y_step_1  y_step_2  y_step_3  y_step_4  y_step_5  \
# Week
# 2009-06-29/2009-07-05       180     115.0     132.0     109.0     120.0
# 2009-07-06/2009-07-12       115     132.0     109.0     120.0     115.0
# 2009-07-13/2009-07-19       132     109.0     120.0     115.0     123.0
# 2009-07-20/2009-07-26       109     120.0     115.0     123.0     205.0
# 2009-07-27/2009-08-02       120     115.0     123.0     205.0     454.0
# ...                         ...       ...       ...       ...       ...
# 2016-04-11/2016-04-17       616     578.0     455.0     305.0     211.0
# 2016-04-18/2016-04-24       578     455.0     305.0     211.0     156.0
# 2016-04-25/2016-05-01       455     305.0     211.0     156.0     124.0
# 2016-05-02/2016-05-08       305     211.0     156.0     124.0      90.0
# 2016-05-09/2016-05-15       211     156.0     124.0      90.0      55.0
#
#                        y_step_6  y_step_7  y_step_8
# Week
# ...

# %%
#Multioutput model
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, shuffle=False)

model = LinearRegression()
model.fit(X_train, y_train)

y_fit = pd.DataFrame(model.predict(X_train), index=X_train.index, columns=y.columns)
y_pred = pd.DataFrame(model.predict(X_test), index=X_test.index, columns=y.columns)

# %%
#학습 세트와 테스트 세트의 RMSE
train_rmse = mean_squared_error(y_train, y_fit, squared=False)
test_rmse = mean_squared_error(y_test, y_pred, squared=False)
print((f"Train RMSE: {train_rmse:.2f}\n" f"Test RMSE: {test_rmse:.2f}"))

palette = dict(palette='husl', n_colors=64)
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(11, 6))
ax1 = flu_trends.FluVisits[y_fit.index].plot(**plot_params, ax=ax1)
ax1 = plot_multistep(y_fit, ax=ax1, palette_kwargs=palette)
_ = ax1.legend(['FluVisits (train)', 'Forecast'])
ax2 = flu_trends.FluVisits[y_pred.index].plot(**plot_params, ax=ax2)
ax2 = plot_multistep(y_pred, ax=ax2, palette_kwargs=palette)
_ = ax2.legend(['FluVisits (test)', 'Forecast'])

#test 데이터가 RMSE가 높아 예측이 덜 정확하고 그래프에서도 실제와 많이 차이남
# Out:
# Train RMSE: 389.12
# Test RMSE: 582.33

# %%
#Direct strategy
# But by applying the Direct reduction strategy, we can still use it to produce multi-step forecasts. 
#This is as easy as wrapping it with scikit-learn's MultiOutputRegressor
from sklearn.multioutput import MultiOutputRegressor

model = MultiOutputRegressor(XGBRegressor())
model.fit(X_train, y_train)

y_fit = pd.DataFrame(model.predict(X_train), index=X_train.index, columns=y.columns)
y_pred = pd.DataFrame(model.predict(X_test), index=X_test.index, columns=y.columns)

# %%
train_rmse = mean_squared_error(y_train, y_fit, squared=False)
test_rmse = mean_squared_error(y_test, y_pred, squared=False)
print((f"Train RMSE: {train_rmse:.2f}\n" f"Test RMSE: {test_rmse:.2f}"))

palette = dict(palette='husl', n_colors=64)
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(11, 6))
ax1 = flu_trends.FluVisits[y_fit.index].plot(**plot_params, ax=ax1)
ax1 = plot_multistep(y_fit, ax=ax1, palette_kwargs=palette)
_ = ax1.legend(['FluVisits (train)', 'Forecast'])
ax2 = flu_trends.FluVisits[y_pred.index].plot(**plot_params, ax=ax2)
ax2 = plot_multistep(y_pred, ax=ax2, palette_kwargs=palette)
_ = ax2.legend(['FluVisits (test)', 'Forecast'])

#train에서는 overfitting
#test에서는 그래도 전에보다는 나음
# Out:
# Train RMSE: 1.22
# Test RMSE: 526.45
